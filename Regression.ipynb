# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data=pd.read_csv('petrol_consumption.csv')

# %%
data
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.00            3571            1976                         0.525
# 1         9.00            4092            1250                         0.572
# 2         9.00            3865            1586                         0.580
# 3         7.50            4870            2351                         0.529
# 4         8.00            4399             431                         0.544
# 5        10.00            5342            1333                         0.571
# 6         8.00            5319           11868                         0.451
# 7         8.00            5126            2138                         0.553
# 8         8.00            4447            8577                         0.529
# 9         7.00            4512            8507                         0.552
# 10        8.00            4391            5939                         0.530
# ...

# %%
data.shape
# Out:
# (48, 5)

# %%
data.describe()
# Out:
#        Petrol_tax  Average_income  Paved_Highways  \
# count   48.000000       48.000000       48.000000
# mean     7.668333     4241.833333     5565.416667
# std      0.950770      573.623768     3491.507166
# min      5.000000     3063.000000      431.000000
# 25%      7.000000     3739.000000     3110.250000
# 50%      7.500000     4298.000000     4735.500000
# 75%      8.125000     4578.750000     7156.000000
# max     10.000000     5342.000000    17782.000000
#
#        Population_Driver_licence(%)  Petrol_Consumption
# count                     48.000000           48.000000
# mean                       0.570333          576.770833
# std                        0.055470          111.885816
# min                        0.451000          344.000000
# 25%                        0.529750          509.500000
# 50%                        0.564500          568.500000
# 75%                        0.595250          632.750000
# max                        0.724000          968.000000

# %%
data.describe().T
# Out:
#                               count         mean          std       min  \
# Petrol_tax                     48.0     7.668333     0.950770     5.000
# Average_income                 48.0  4241.833333   573.623768  3063.000
# Paved_Highways                 48.0  5565.416667  3491.507166   431.000
# Population_Driver_licence(%)   48.0     0.570333     0.055470     0.451
# Petrol_Consumption             48.0   576.770833   111.885816   344.000
#
#                                      25%        50%         75%        max
# Petrol_tax                       7.00000     7.5000     8.12500     10.000
# Average_income                3739.00000  4298.0000  4578.75000   5342.000
# Paved_Highways                3110.25000  4735.5000  7156.00000  17782.000
# Population_Driver_licence(%)     0.52975     0.5645     0.59525      0.724
# Petrol_Consumption             509.50000   568.5000   632.75000    968.000

# %%
data.isnull().values.any()
# Out:
# False

# %%
data.isnull().values.any()
# Out:
# False

# %%
data.isnull().values.any()
# Out:
# False

# %%
data.isnull().sum()
# Out:
# Petrol_tax                      0
# Average_income                  0
# Paved_Highways                  0
# Population_Driver_licence(%)    0
# Petrol_Consumption              0
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data.Petrol_tax.mean()
# Out:
# 7.668333333333333

# %%
data['Petrol_tax'].mean()
# Out:
# 7.668333333333333

# %%
data
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.00            3571            1976                         0.525
# 1         9.00            4092            1250                         0.572
# 2         9.00            3865            1586                         0.580
# 3         7.50            4870            2351                         0.529
# 4         8.00            4399             431                         0.544
# 5        10.00            5342            1333                         0.571
# 6         8.00            5319           11868                         0.451
# 7         8.00            5126            2138                         0.553
# 8         8.00            4447            8577                         0.529
# 9         7.00            4512            8507                         0.552
# 10        8.00            4391            5939                         0.530
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(data)

# %%
X=data.iloc[:,:-1]

# %%
X
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)
# 0         9.00            3571            1976                         0.525
# 1         9.00            4092            1250                         0.572
# 2         9.00            3865            1586                         0.580
# 3         7.50            4870            2351                         0.529
# 4         8.00            4399             431                         0.544
# 5        10.00            5342            1333                         0.571
# 6         8.00            5319           11868                         0.451
# 7         8.00            5126            2138                         0.553
# 8         8.00            4447            8577                         0.529
# 9         7.00            4512            8507                         0.552
# 10        8.00            4391            5939                         0.530
# ...

# %%
data.iloc[:,:-2]
# Out:
#     Petrol_tax  Average_income  Paved_Highways
# 0         9.00            3571            1976
# 1         9.00            4092            1250
# 2         9.00            3865            1586
# 3         7.50            4870            2351
# 4         8.00            4399             431
# 5        10.00            5342            1333
# 6         8.00            5319           11868
# 7         8.00            5126            2138
# 8         8.00            4447            8577
# 9         7.00            4512            8507
# 10        8.00            4391            5939
# 11        7.50            5126           14186
# 12        7.00            4817            6930
# 13        7.00            4207            6580
# 14        7.00            4332            8159
# 15        7.00            4318           10340
# 16        7.00            4206            8508
# 17        7.00            3718            4725
# 18        7.00            4716            5915
# ...

# %%
data.iloc[:-10,:-3]
# Out:
#     Petrol_tax  Average_income
# 0         9.00            3571
# 1         9.00            4092
# 2         9.00            3865
# 3         7.50            4870
# 4         8.00            4399
# 5        10.00            5342
# 6         8.00            5319
# 7         8.00            5126
# 8         8.00            4447
# 9         7.00            4512
# 10        8.00            4391
# 11        7.50            5126
# 12        7.00            4817
# 13        7.00            4207
# 14        7.00            4332
# 15        7.00            4318
# 16        7.00            4206
# 17        7.00            3718
# 18        7.00            4716
# 19        8.50            4341
# 20        7.00            4593
# 21        8.00            4983
# 22        9.00            4897
# 23        9.00            4258
# 24        8.50            4574
# 25        9.00            3721
# 26        8.00            3448
# 27        7.50            3846
# 28        8.00            4188
# ...

# %%
data
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.00            3571            1976                         0.525
# 1         9.00            4092            1250                         0.572
# 2         9.00            3865            1586                         0.580
# 3         7.50            4870            2351                         0.529
# 4         8.00            4399             431                         0.544
# 5        10.00            5342            1333                         0.571
# 6         8.00            5319           11868                         0.451
# 7         8.00            5126            2138                         0.553
# 8         8.00            4447            8577                         0.529
# 9         7.00            4512            8507                         0.552
# 10        8.00            4391            5939                         0.530
# ...

# %%
Y=data.iloc[:,-1]

# %%
Y
# Out:
# 0     541
# 1     524
# 2     561
# 3     414
# 4     410
# 5     457
# 6     344
# 7     467
# 8     464
# 9     498
# 10    580
# 11    471
# 12    525
# 13    508
# 14    566
# 15    635
# 16    603
# 17    714
# 18    865
# 19    640
# 20    649
# 21    540
# 22    464
# 23    547
# 24    460
# 25    566
# 26    577
# 27    631
# 28    574
# 29    534
# 30    571
# 31    554
# 32    577
# 33    628
# 34    487
# 35    644
# 36    640
# 37    704
# 38    648
# 39    968
# 40    587
# 41    699
# 42    632
# 43    591
# 44    782
# 45    510
# 46    610
# 47    524
# Name: Petrol_Consumption, dtype: int64

# %%
data.iloc[:,-2]
# Out:
# 0     0.525
# 1     0.572
# 2     0.580
# 3     0.529
# 4     0.544
# 5     0.571
# 6     0.451
# 7     0.553
# 8     0.529
# 9     0.552
# 10    0.530
# 11    0.525
# 12    0.574
# 13    0.545
# 14    0.608
# 15    0.586
# 16    0.572
# 17    0.540
# 18    0.724
# 19    0.677
# 20    0.663
# 21    0.602
# 22    0.511
# 23    0.517
# 24    0.551
# 25    0.544
# 26    0.548
# 27    0.579
# 28    0.563
# 29    0.493
# 30    0.518
# 31    0.513
# 32    0.578
# 33    0.547
# 34    0.487
# 35    0.629
# 36    0.566
# 37    0.586
# 38    0.663
# 39    0.672
# 40    0.626
# 41    0.563
# 42    0.603
# 43    0.508
# 44    0.672
# 45    0.571
# 46    0.623
# 47    0.593
# Name: Population_Driver_licence(%), dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
Xtrain,Xtest,Ytrain,Ytest=train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
Xtrain.shape,Ytrain.shape,Xtest.shape,Ytest.shape
# Out:
# ((38, 4), (38,), (10, 4), (10,))

# %%
Ytrain,Ytest
# Out:
# (11    471
#  31    554
#  33    628
#  27    631
#  47    524
#  2     561
#  46    610
#  18    865
#  15    635
#  28    574
#  22    464
#  16    603
#  41    699
#  20    649
#  42    632
#  8     464
#  13    508
#  25    566
#  5     457
#  17    714
#  35    644
#  14    566
#  38    648
#  1     524
#  12    525
#  43    591
#  24    460
#  6     344
#  23    547
#  36    640
#  21    540
#  19    640
#  9     498
#  39    968
#  45    510
#  3     414
#  0     541
#  44    782
#  Name: Petrol_Consumption, dtype: int64,
#  29    534
#  4     410
#  26    577
#  30    571
#  32    577
#  37    704
#  34    487
#  40    587
#  7     467
#  10    580
#  Name: Petrol_Consumption, dtype: int64)

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# model=LinearRegression()

# %%
model=LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
model.fit(Xtrain,Ytrain)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([-4.00166602e+01, -6.54126674e-02, -4.74073380e-03,  1.34186212e+03])

# %%
model.intercept_
# Out:
# 425.59933220324103

# %%
Ypredict=model.predict(Xtest)

# %%
Ypredict
# Out:
# array([469.39198872, 545.64546431, 589.66839402, 569.7304133 ,
#        649.77480909, 646.63116356, 511.60814841, 672.47517717,
#        502.07478157, 501.2707342 ])

# %%
Ytest
# Out:
# 29    534
# 4     410
# 26    577
# 30    571
# 32    577
# 37    704
# 34    487
# 40    587
# 7     467
# 10    580
# Name: Petrol_Consumption, dtype: int64

# %%
results=pd.DataFrame({"Actual":Ytest,
                      "Predicted":Ypredict})

# %%
results
# Out:
#     Actual   Predicted
# 29     534  469.391989
# 4      410  545.645464
# 26     577  589.668394
# 30     571  569.730413
# 32     577  649.774809
# 37     704  646.631164
# 34     487  511.608148
# 40     587  672.475177
# 7      467  502.074782
# 10     580  501.270734

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(Ytest,Ypredict)
# Out:
# 56.82224747896471

# %%
metrics.mean_squared_error(Ytest,Ypredict)
# Out:
# 4666.344787588364

# %%
np.sqrt(metrics.mean_squared_error(Ytest,Ypredict))
# Out:
# 68.3106491521517

# %%
model.coef_
# Out:
# array([-4.00166602e+01, -6.54126674e-02, -4.74073380e-03,  1.34186212e+03])

# %%
model.intercept_
# Out:
# 425.59933220324103

# %%
coefficient = pd.DataFrame(model.coef_,X.columns)

# %%
coefficient
# Out:
#                                         0
# Petrol_tax                     -40.016660
# Average_income                  -0.065413
# Paved_Highways                  -0.004741
# Population_Driver_licence(%)  1341.862121

# %%
coefficient = pd.DataFrame(model.coef_,X.columns,columns=['Coefficient'])

# %%
coefficient
# Out:
#                               Coefficient
# Petrol_tax                     -40.016660
# Average_income                  -0.065413
# Paved_Highways                  -0.004741
# Population_Driver_licence(%)  1341.862121

# %%
pd.DataFrame(model.coef_,X.columns,columns=["Coefficient"])
# Out:
#                               Coefficient
# Petrol_tax                     -40.016660
# Average_income                  -0.065413
# Paved_Highways                  -0.004741
# Population_Driver_licence(%)  1341.862121

# %% [markdown]
# # Linear

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('student_scores.csv')

# %%
data
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
data.columns
# Out:
# Index(['Hours', 'Scores'], dtype='object')

# %%
data.Hours,data.Scores
# Out:
# (0     2.5
#  1     5.1
#  2     3.2
#  3     8.5
#  4     3.5
#  5     1.5
#  6     9.2
#  7     5.5
#  8     8.3
#  9     2.7
#  10    7.7
#  11    5.9
#  12    4.5
#  13    3.3
#  14    1.1
#  15    8.9
#  16    2.5
#  17    1.9
#  18    6.1
#  19    7.4
#  20    2.7
#  21    4.8
#  22    3.8
#  23    6.9
#  24    7.8
#  Name: Hours, dtype: float64,
#  0     21
#  1     47
#  2     27
#  3     75
#  4     30
#  5     20
#  6     88
#  7     60
#  8     81
#  9     25
#  10    85
#  11    62
#  12    41
#  13    42
#  14    17
#  15    95
#  16    30
#  17    24
#  18    67
#  19    69
#  20    30
#  21    54
#  22    35
#  23    76
#  24    86
#  Name: Scores, dtype: int64)

# %%
data.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
data.describe().T
# Out:
#         count    mean        std   min   25%   50%   75%   max
# Hours    25.0   5.012   2.525094   1.1   2.7   4.8   7.4   9.2
# Scores   25.0  51.480  25.286887  17.0  30.0  47.0  75.0  95.0

# %%
data.dtypes
# Out:
# Hours     float64
# Scores      int64
# dtype: object

# %%
data.head(10)
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30
# 5    1.5      20
# 6    9.2      88
# 7    5.5      60
# 8    8.3      81
# 9    2.7      25

# %%
data.tail(5)
# Out:
#     Hours  Scores
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
plt.figure(figsize=(13,8))
plt.scatter(data.Hours,data.Scores)
plt.xlabel("Hours --->")
plt.ylabel("Scores")
plt.show()

# %%
data.plot(x='Hours',y='Scores',style="o")

plt.xlabel("Hours Spent")
plt.ylabel("Obtained Scores")
plt.show()

# %%
data.plot(x='Hours',y='Scores',style="+")

plt.xlabel("Hours Spent")
plt.ylabel("Obtained Scores")
plt.show()

# %%
data.shape
# Out:
# (25, 2)

# %%
x=data.iloc[1:5,:]
x
# Out:
#    Hours  Scores
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
x.values
# Out:
# array([[ 5.1, 47. ],
#        [ 3.2, 27. ],
#        [ 8.5, 75. ],
#        [ 3.5, 30. ]])

# %%
x=data.iloc[1:5,:].values
x
# Out:
# array([[ 5.1, 47. ],
#        [ 3.2, 27. ],
#        [ 8.5, 75. ],
#        [ 3.5, 30. ]])

# %%
data.iloc[:]
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
data.iloc[:,:]
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
data.iloc[:,1]
# Out:
# 0     21
# 1     47
# 2     27
# 3     75
# 4     30
# 5     20
# 6     88
# 7     60
# 8     81
# 9     25
# 10    85
# 11    62
# 12    41
# 13    42
# 14    17
# 15    95
# 16    30
# 17    24
# 18    67
# 19    69
# 20    30
# 21    54
# 22    35
# 23    76
# 24    86
# Name: Scores, dtype: int64

# %%
data.iloc[:,-1]
# Out:
# 0     21
# 1     47
# 2     27
# 3     75
# 4     30
# 5     20
# 6     88
# 7     60
# 8     81
# 9     25
# 10    85
# 11    62
# 12    41
# 13    42
# 14    17
# 15    95
# 16    30
# 17    24
# 18    67
# 19    69
# 20    30
# 21    54
# 22    35
# 23    76
# 24    86
# Name: Scores, dtype: int64

# %%
data.iloc[:,-1].values
# Out:
# array([21, 47, 27, 75, 30, 20, 88, 60, 81, 25, 85, 62, 41, 42, 17, 95, 30,
#        24, 67, 69, 30, 54, 35, 76, 86], dtype=int64)

# %%
data.iloc[:,-1].values #Shesh er  column ta dekhabe
# Out:
# array([21, 47, 27, 75, 30, 20, 88, 60, 81, 25, 85, 62, 41, 42, 17, 95, 30,
#        24, 67, 69, 30, 54, 35, 76, 86], dtype=int64)

# %%
X=data.iloc[:,:-1].values #2D array , puro dataset theke shesher column baad dibe

# %%
X
# Out:
# array([[2.5],
#        [5.1],
#        [3.2],
#        [8.5],
#        [3.5],
#        [1.5],
#        [9.2],
#        [5.5],
#        [8.3],
#        [2.7],
#        [7.7],
#        [5.9],
#        [4.5],
#        [3.3],
#        [1.1],
#        [8.9],
#        [2.5],
#        [1.9],
#        [6.1],
#        [7.4],
#        [2.7],
#        [4.8],
#        [3.8],
#        [6.9],
#        [7.8]])

# %%
Y=data.iloc[:,1].values #Single array

# %%
Y
# Out:
# array([21, 47, 27, 75, 30, 20, 88, 60, 81, 25, 85, 62, 41, 42, 17, 95, 30,
#        24, 67, 69, 30, 54, 35, 76, 86], dtype=int64)

# %%
from sklearn.model_selection import train_test_split

# %%
Xtrain,Xtest,Ytrain,Ytest=train_test_split(X,Y,test_size=0.2,random_state=20)

# %%
Xtrain.shape,Xtest.shape,Ytrain.shape,Ytest.shape
# Out:
# ((20, 1), (5, 1), (20,), (5,))

# %% [markdown]
# # X always  array hobe and Y always 1D array hobe

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(Xtrain,Ytrain)
# Out:
# LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
model.fit(Xtrain,Ytrain)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 3.3436414413187023

# %%
model.coef_
# Out:
# array([9.67107504])

# %%
Ypredicted=model.predict(Xtest)

# %%
results=pd.DataFrame({"Actual Scores":Ytest,
                      "Predicted Scores":Ypredicted})

# %%
results
# Out:
#    Actual Scores  Predicted Scores
# 0             69         74.909597
# 1             76         70.074059
# 2             41         46.863479
# 3             30         37.192404
# 4             67         62.337199

# %%
results.plot(x='Actual Scores',y='Predicted Scores',style='o')
plt.xlabel("Actual Scores")
plt.ylabel("Predicted Scores")
plt.title("Prediction")
plt.show()

# %%
plt.scatter(results['Actual Scores'],results['Predicted Scores'])
plt.show()

# %%
plt.scatter(data['Hours'],data['Scores'])
plt.show()

# %%
plt.scatter(data.Hours,data.Scores)
Y_predict= model.coef_*data.Hours+model.intercept_
plt.plot(data['Hours'],Y_predict,color='red')
plt.show()

# %%
#Evaluate the model

# %%
from sklearn import metrics

# %% [markdown]
# # Accuracy

# %%
from sklearn import metrics

# %%
metrics.r2_score(Ytest,Ypredicted)
# Out:
# 0.8880613623447959

# %%
metrics.mean_absolute_error(Ytest,Ypredicted)
# Out:
# 5.910844306461269

# %%
metrics.mean_squared_error(Ytest,Ypredicted)
# Out:
# 35.57857659233007

# %%
np.sqrt(metrics.mean_squared_error(Ytest,Ypredicted))
# Out:
# 5.964778000255339

# %%
Ytest.reshape(-1,1)
# Out:
# array([[69],
#        [76],
#        [41],
#        [30],
#        [67]], dtype=int64)

# %%
Ypredicted.reshape(-1,1)
# Out:
# array([[74.90959672],
#        [70.0740592 ],
#        [46.86347911],
#        [37.19240407],
#        [62.33719917]])

# %%
Ytest,Ypredicted
# Out:
# (array([69, 76, 41, 30, 67], dtype=int64),
#  array([74.90959672, 70.0740592 , 46.86347911, 37.19240407, 62.33719917]))
